# %% [markdown]
# # Minimal_Monthly_Temperatures_Time_Series_Forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import Series
import warnings
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.api import Holt
from statsmodels.tsa.stattools import adfuller 
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
from pandas.plotting import autocorrelation_plot

# %% [markdown]
# #### The dataset contains the minimum temperatures over 10 years (1981-1990) in the city Melbourne, Australia

# %%
train=pd.read_csv("Dataset/train_temperature_time_series.csv")
test=pd.read_csv("Dataset/test_temperature_time_series.csv")

# %%
train.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
test.head()
# Out:
#          Date  Temp
# 0  1990-01-01  14.8
# 1  1990-01-02  13.3
# 2  1990-01-03  15.6
# 3  1990-01-04  14.5
# 4  1990-01-05  14.3

# %%
train.dtypes, test.dtypes
# Out:
# (Date     object
#  Temp    float64
#  dtype: object,
#  Date     object
#  Temp    float64
#  dtype: object)

# %%
train.shape, test.shape
# Out:
# ((3285, 2), (365, 2))

# %%
train['Date']=pd.to_datetime(train.Date,format= '%Y-%m-%d')
test['Date']=pd.to_datetime(test.Date,format= '%Y-%m-%d')

# %%
for i in (train,test):
  i['year']=i.Date.dt.year
  i['month']=i.Date.dt.month
  i['day']=i.Date.dt.day

# %% [markdown]
# ### Exploratory Data Analysis and Visualization

# %%
train.set_index('Date',inplace=True)

# %% [markdown]
# #### Plotting the data of minimal temperature over time

# %%
df=train
ts=df['Temp']
plt.figure(figsize=(20,10))
plt.plot(ts,label='Minimal Temperature')
plt.title('Time Series')
plt.xlabel('Time(year/month)')
plt.ylabel('Minimal Temperature')
plt.legend(loc='best')

# %% [markdown]
# #### Mean of minimal temperatures yearwise

# %%
train.groupby('year')['Temp'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### Mean of minimal temperatures monthwise

# %%
train.groupby('month')['Temp'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
# Trend including month and year data
tem=train.groupby(['year', 'month'])['Temp'].mean()
tem.plot(figsize=(15,5),title='Minimal Temperature (Year, Month)',fontsize=14)
#Thus we understand that it is seasonal trend
# Out:
# <AxesSubplot:title={'center':'Minimal Temperature (Year, Month)'}, xlabel='year,month'>

# %%
train.Temp.plot(figsize=(20,8),title='Daily Ridership',fontsize=20,label='train')
plt.xlabel('Date')
plt.ylabel('Minimal Temperature')
plt.legend(loc='best')
plt.show()

# %%
#To make graph smooth we will use monthly predictions
monthly_train=train.resample('M').mean()

# %%
monthly_train.Temp.plot(figsize=(15,8),title='Daily Ridership',fontsize=20,label='train')
plt.xlabel('Date')
plt.ylabel('Minimum Temperature')
plt.legend(loc='best')
plt.show()
